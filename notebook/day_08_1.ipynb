# %% [markdown]
# # AoC Day 8 part 1
#
# - https://adventofcode.com/2024/day/8
#
# - https://adventofcode.com/2024/day/8/input

# %%
import sys

sys.path.insert(0, '../src/')
import day_08 as d8

# %% [markdown]
# ## Example

# %%
# make the 2D map

ant_map_input = '''
............
........0...
.....0......
.......0....
....0.......
......A.....
............
............
........A...
.........A..
............
............
''' 

ant_map = [ list(a) for a in ant_map_input.split() ]

ant_map
# Out:
# [['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '0', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '0', '.', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '0', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '0', '.', '.', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', 'A', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', 'A', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', 'A', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']]

# %%
# how many different antennas (freq) are there

antennas_types = set(list(ant_map_input))
antennas_types = [a for a in antennas_types if a.isalnum()]
antennas_types
# Out:
# ['A', '0']

# %%
# find antenna locations

ant_coords = dict() 

for ant_type in antennas_types:
    ant_coords[ant_type] = list() 
    
    for x in range(len(ant_map[0])):
        for y in range(len(ant_map)):
            if ant_map[y][x] == ant_type: ant_coords[ant_type].append( (x, y) )
            
print(ant_coords)
# Out:
# {'A': [(6, 5), (8, 8), (9, 9)], '0': [(4, 4), (5, 2), (7, 3), (8, 1)]}

# %%
# Find antinodes for each pair or antennas 

antinodes = d8.find_antinodes(ant_map, ant_coords, True )
# Out:
# A (6, 5) (8, 8) -2 -3 0.6666666666666666 || (4, 2) (8, 8) True
# 	|| (4, 2) (8, 8) (6, 5) (10, 11)
# A (6, 5) (9, 9) -3 -4 0.75 || (3, 1) (9, 9) True
# 	|| (3, 1) (9, 9) (6, 5) (12, 13)
# A (8, 8) (9, 9) -1 -1 1.0 || (7, 7) (9, 9) True
# 	|| (7, 7) (9, 9) (8, 8) (10, 10)
# 0 (4, 4) (5, 2) -1 2 -0.5 || (3, 6) (5, 2) True
# 	|| (3, 6) (5, 2) (4, 4) (6, 0)
# 0 (4, 4) (7, 3) -3 1 -3.0 || (1, 5) (7, 3) True
# 	|| (1, 5) (7, 3) (4, 4) (10, 2)
# 0 (4, 4) (8, 1) -4 3 -1.3333333333333333 || (0, 7) (8, 1) True
# 	|| (0, 7) (8, 1) (4, 4) (12, -2)
# 0 (5, 2) (7, 3) -2 -1 2.0 || (3, 1) (7, 3) True
# 	|| (3, 1) (7, 3) (5, 2) (9, 4)
# 0 (5, 2) (8, 1) -3 1 -3.0 || (2, 3) (8, 1) True
# 	|| (2, 3) (8, 1) (5, 2) (11, 0)
# 0 (7, 3) (8, 1) -1 2 -0.5 || (6, 5) (8, 1) True
# 	|| (6, 5) (8, 1) (7, 3) (9, -1)

# %%
antinodes = set( [a2 for a1, a2, _, _ in antinodes] )
print(len(antinodes))
antinodes
# Out:
# 14
# {(0, 7),
#  (1, 5),
#  (2, 3),
#  (3, 1),
#  (3, 6),
#  (4, 2),
#  (6, 0),
#  (6, 5),
#  (7, 7),
#  (9, 4),
#  (10, 2),
#  (10, 10),
#  (10, 11),
#  (11, 0)}

# %% [markdown]
# ## Input file

# %%
fp = '../data/day_08_1.txt'

with open(fp, 'r') as f_in:
   ant_map_input = f_in.readlines()

ant_map = [ list(a.strip()) for a in ant_map_input ]
#ant_map

# %%
# how many different antennas (freq) are there

antennas_types = set(list(''.join(ant_map_input)))
antennas_types = [a for a in antennas_types if a.isalnum()]
print( antennas_types )
# Out:
# ['K', 'B', '7', 'V', 'q', 'e', '9', '3', '0', 'b', 'I', 'T', 'a', 'i', 'D', 'G', 'y', 'W', '6', '2', 'A', '5', 'k', 'v', '4', 'm', 'g', 'Q', '8', 'Y', 'E', '1', 't', 'w', 'M', 'd']

# %%
# find antenna locations

ant_coords = dict() 

for ant_type in antennas_types:
    ant_coords[ant_type] = list() 
    
    for x in range(len(ant_map[0])):
        for y in range(len(ant_map)):
            if ant_map[y][x] == ant_type: ant_coords[ant_type].append( (x, y) )
print(ant_coords)
# Out:
# {'K': [(1, 1), (10, 0), (13, 8), (14, 23)], 'B': [(31, 16), (38, 6), (45, 7)], '7': [(15, 23), (36, 34), (37, 30), (48, 21)], 'V': [(30, 23), (37, 41), (43, 46), (44, 40)], 'q': [(5, 39), (10, 33), (12, 40), (27, 36)], 'e': [(4, 28), (7, 27), (11, 6), (18, 17)], '9': [(0, 38), (2, 25), (3, 33), (7, 32)], '3': [(30, 29), (31, 21), (35, 30), (36, 28)], '0': [(40, 22), (41, 19), (43, 36), (44, 29)], 'b': [(8, 38), (10, 35), (11, 25), (15, 14)], 'I': [(34, 25), (37, 24), (38, 22), (41, 29)], 'T': [(35, 16), (36, 6), (37, 15), (42, 13)], 'a': [(9, 29), (10, 32), (17, 20), (22, 21)], 'i': [(1, 42), (3, 41), (4, 38), (10, 31)], 'D': [(26, 7), (35, 6), (38, 2), (49, 3)], 'G': [(41, 43), (44, 47), (49, 48)], 'y': [(40, 10), (43, 12)], 'W': [(32, 16), (33, 15), (40, 17), (49, 18)], '6': [(35, 19), (36, 3), (43, 14)], '2': [(6, 32), (7, 38), (8, 39), (9, 45)], 'A': [(33, 7), (34, 1), (35, 0), (44, 2)], '5': [(36, 37), (37, 48), (38, 46), (41, 45)], 'k': [(8, 19), (17, 12), (26, 14), (27, 9)], 'v': [(16, 36), (19, 35), (24, 29), (27, 30)], '4': [(9, 6), (17, 17), (18, 10), (20, 21)], 'm': [(13, 22), (18, 31), (21, 33), (30, 32)], 'g': [(12, 17), (14, 12), (25, 18), (33, 21)], 'Q': [(3, 32), (4, 24), (10, 29), (11, 13)], '8': [(12, 44), (26, 45), (33, 49), (41, 38)], 'Y': [(20, 34), (21, 39), (22, 35), (29, 44)], 'E': [(16, 42), (17, 35), (18, 37), (19, 28)], '1': [(4, 34), (6, 29), (7, 18), (13, 35)], 't': [(16, 28), (19, 29), (22, 33), (29, 30)], 'w': [(3, 10), (5, 13), (8, 11), (16, 16)], 'M': [(24, 39), (26, 34), (27, 31), (29, 42)], 'd': [(19, 26), (20, 7), (29, 5), (32, 12)]}

# %%
antinodes = d8.find_antinodes(ant_map, ant_coords)

# %%
# 254
antinodes = set( [a2 for a1, a2, _, _ in antinodes] )
print(len(antinodes))
antinodes
# Out:
# 254
# {(0, 2),
#  (0, 6),
#  (0, 45),
#  (1, 1),
#  (1, 7),
#  (1, 17),
#  (1, 29),
#  (1, 38),
#  (2, 15),
#  (2, 39),
#  (2, 40),
#  (2, 44),
#  (3, 6),
#  (3, 11),
#  (3, 19),
#  (3, 26),
#  (3, 44),
#  (3, 48),
#  (4, 12),
#  (4, 25),
#  (4, 41),
#  (5, 11),
#  (5, 16),
#  (5, 26),
#  (5, 31),
#  (5, 35),
#  (5, 40),
#  (5, 42),
#  (6, 28),
#  (6, 30),
#  (6, 37),
#  (6, 40),
#  (6, 41),
#  (7, 15),
#  (7, 16),
#  (7, 33),
#  (7, 34),
#  (7, 36),
#  (8, 2),
#  (8, 7),
#  (8, 10),
#  (8, 13),
#  (8, 24),
#  (8, 26),
#  (8, 43),
#  (8, 44),
#  (9, 28),
#  (9, 40),
#  (9, 45),
#  (9, 47),
#  (10, 2),
#  (10, 22),
#  (10, 23),
#  (10, 26),
#  (10, 46),
#  (11, 9),
#  (11, 24),
#  (11, 31),
#  (11, 35),
#  (11, 40),
#  (12, 15),
#  (12, 19),
#  (12, 32),
#  (12, 34),
#  (12, 39),
#  (13, 12),
#  (13, 27),
#  (13, 34),
#  (13, 37),
#  (14, 12),
#  (14, 13),
#  (14, 26),
#  (14, 41),
#  (14, 47),
#  (15, 14),
#  (15, 26),
#  (15, 27),
#  (15, 29),
#  (15, 36),
#  (15, 38),
#  (15, 42),
#  (15, 49),
#  (16, 6),
#  (16, 7),
#  (16, 16),
#  (16, 24),
#  (16, 25),
#  (16, 33),
#  (16, 34),
#  (17, 0),
#  (17, 8),
#  (17, 12),
#  (17, 15),
#  (17, 21),
#  (17, 25),
#  (17, 26),
#  (17, 46),
#  (18, 2),
#  (18, 28),
#  (18, 33),
#  (18, 45),
#  (18, 46),
#  (19, 3),
#  (19, 20),
#  (19, 29),
#  (19, 36),
#  (19, 39),
#  (19, 41),
#  (20, 19),
#  (20, 32),
#  (20, 41),
#  (20, 43),
#  (21, 9),
#  (21, 21),
#  (21, 28),
#  (21, 47),
#  (22, 12),
#  (22, 14),
#  (22, 30),
#  (22, 32),
#  (22, 34),
#  (22, 36),
#  (22, 44),
#  (23, 5),
#  (23, 25),
#  (23, 26),
#  (23, 31),
#  (23, 40),
#  (24, 0),
#  (24, 8),
#  (24, 15),
#  (24, 21),
#  (24, 26),
#  (24, 30),
#  (24, 35),
#  (24, 36),
#  (24, 47),
#  (25, 11),
#  (25, 15),
#  (25, 19),
#  (25, 20),
#  (25, 28),
#  (25, 37),
#  (26, 5),
#  (26, 13),
#  (26, 14),
#  (26, 39),
#  (27, 1),
#  (27, 12),
#  (27, 14),
#  (27, 19),
#  (27, 21),
#  (27, 22),
#  (27, 24),
#  (27, 45),
#  (28, 4),
#  (28, 19),
#  (28, 28),
#  (28, 29),
#  (28, 38),
#  (29, 7),
#  (29, 22),
#  (29, 23),
#  (29, 37),
#  (29, 44),
#  (30, 23),
#  (30, 28),
#  (30, 31),
#  (30, 42),
#  (31, 5),
#  (31, 14),
#  (31, 16),
#  (31, 17),
#  (31, 26),
#  (31, 29),
#  (31, 36),
#  (32, 6),
#  (32, 10),
#  (32, 13),
#  (32, 17),
#  (32, 22),
#  (33, 2),
#  (33, 17),
#  (33, 19),
#  (33, 38),
#  (34, 10),
#  (34, 14),
#  (34, 26),
#  (34, 28),
#  (34, 32),
#  (34, 35),
#  (34, 45),
#  (35, 13),
#  (35, 15),
#  (35, 16),
#  (35, 19),
#  (35, 25),
#  (35, 26),
#  (35, 38),
#  (35, 47),
#  (36, 15),
#  (36, 24),
#  (36, 26),
#  (36, 27),
#  (37, 6),
#  (37, 8),
#  (37, 26),
#  (37, 49),
#  (38, 3),
#  (38, 9),
#  (38, 19),
#  (38, 24),
#  (38, 26),
#  (38, 39),
#  (39, 2),
#  (39, 14),
#  (39, 20),
#  (39, 25),
#  (39, 31),
#  (39, 39),
#  (39, 44),
#  (39, 46),
#  (40, 23),
#  (40, 31),
#  (40, 46),
#  (41, 24),
#  (41, 35),
#  (42, 16),
#  (42, 19),
#  (42, 27),
#  (42, 32),
#  (42, 33),
#  (42, 43),
#  (44, 5),
#  (44, 9),
#  (44, 17),
#  (44, 36),
#  (44, 39),
#  (44, 44),
#  (45, 22),
#  (45, 34),
#  (45, 42),
#  (46, 14),
#  (47, 11),
#  (47, 19),
#  (47, 39),
#  (47, 42),
#  (48, 18),
#  (48, 20),
#  (48, 33),
#  (48, 36),
#  (49, 10),
#  (49, 27),
#  (49, 33)}
