# %% [markdown]
# # AoC Day 5 part 2
#
# - https://adventofcode.com/2024/day/5
#
# - https://adventofcode.com/2024/day/5/input

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/python/3.12.1/lib/python3.12/site-packages (4.67.1)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from tqdm import tqdm
import sys

sys.path.insert(0, '../src/')
import day_05 as d5

# %% [markdown]
# ## Example

# %%
input = '''
47|53
97|13
97|61
97|47
75|29
61|13
75|53
29|13
97|29
53|29
61|53
97|53
61|29
47|13
75|47
97|75
47|61
75|61
47|29
75|13
53|13

75,47,61,53,29
97,61,53,29,13
75,29,13
75,97,47,61,53
61,13,29
97,13,75,29,47
'''

# %%
# get the rules and manuals
rules, manuals = d5.process_input(input)

print('Rules: ', rules )
print('Manuals: ', manuals)
# Out:
# Rules:  ['47|53', '97|13', '97|61', '97|47', '75|29', '61|13', '75|53', '29|13', '97|29', '53|29', '61|53', '97|53', '61|29', '47|13', '75|47', '97|75', '47|61', '75|61', '47|29', '75|13', '53|13']
# Manuals:  ['75,47,61,53,29', '97,61,53,29,13', '75,29,13', '75,97,47,61,53', '61,13,29', '97,13,75,29,47']

# %%
# Get invalid manuals 
 
manual_invalid = d5.find_invalid_manuals(rules, manuals, True)

manual_invalid
# Out:
# VALID ['75', '47', '61', '53', '29']
# VALID ['97', '61', '53', '29', '13']
# VALID ['75', '29', '13']
# INVALID ['75', '97', '47', '61', '53']
# INVALID ['61', '13', '29']
# INVALID ['97', '13', '75', '29', '47']
# [['75', '97', '47', '61', '53'],
#  ['61', '13', '29'],
#  ['97', '13', '75', '29', '47']]

# %%
# build a directional graph based on given rules

G = d5.build_rule_graph(rules)

G.edges()
# Out:
# OutEdgeView([('47', '53'), ('47', '13'), ('47', '61'), ('47', '29'), ('53', '29'), ('53', '13'), ('97', '13'), ('97', '61'), ('97', '47'), ('97', '29'), ('97', '53'), ('97', '75'), ('61', '13'), ('61', '53'), ('61', '29'), ('75', '29'), ('75', '53'), ('75', '47'), ('75', '61'), ('75', '13'), ('29', '13')])

# %%
# For each invalid manual, fix it by
# - build subgraph Gs based on rule graph G (reduce search space)
# - Using Gs
#   - find all start nodes and leaf nodes
#   - find all path between start nodes and leave nodes (valid manuals)

manual_invalid_fixed = list() 

for m in manual_invalid:
    m_fixed = d5.fix_manual_graph(G, rules, m)

    if m_fixed != None: manual_invalid_fixed.append(m_fixed)

manual_invalid_fixed
# Out:
# [['97', '75', '47', '61', '53'],
#  ['61', '29', '13'],
#  ['97', '75', '47', '29', '13']]

# %%
d5.sum_middle_numbers(manual_invalid_fixed)
# Out:
# 123

# %% [markdown]
# ## Input file

# %%
fp = '../data/day_05_1.txt'

with open(fp, 'r') as f_in:
    rules, manuals = d5.process_input(f_in.readlines())

# print('Rules: ', rules )
# print('Manuals: ', manuals)

# %%
manual_invalid = d5.find_invalid_manuals(rules, manuals)

print(len(manual_invalid))
print( manual_invalid )
# Out:
# 103
# [['98', '37', '47', '35', '22', '73', '76', '36', '67', '39', '69', '82', '45'], ['37', '98', '86', '23', '42', '91', '96'], ['34', '29', '77', '33', '89', '55', '97', '62', '11'], ['93', '59', '98', '94', '55', '37', '82', '47', '19', '33', '22', '24', '96', '72', '67', '77', '23'], ['23', '35', '63', '37', '69', '98', '47', '36', '96', '82', '19', '91', '57', '39', '89', '45', '24', '22', '94'], ['72', '35', '93', '87', '47', '96', '82', '41', '37', '45', '23', '76', '98', '24', '67', '63', '59', '75', '19', '94', '69', '22', '77'], ['87', '72', '91', '67', '24', '76', '47', '57', '75', '22', '73', '35', '19'], ['36', '75', '98', '73', '24', '47', '87', '76', '89', '45', '96', '94', '35', '39', '63', '69', '57', '42', '22', '72', '23'], ['49', '86', '75', '29', '68', '39', '35', '43', '91', '73', '38', '14', '57', '97', '34', '66', '11', '62', '42', '53', '85', '36', '89'], ['76', '37', '47', '94', '93', '19', '45', '91', '22', '36', '77', '69', '98', '87', '82', '75', '41'], ['37', '94', '98', '45', '19', '87', '35', '93', '72', '39', '77', '22', '63', '47', '23', '24', '91', '69', '75', '96', '36'], ['41', '93', '82', '94', '31', '22', '96', '72', '59', '38', '76', '77', '67', '56', '33', '19', '63', '99', '29'], ['69', '96', '91', '45', '87', '22', '72', '55', '67', '23', '94', '59', '76', '77', '24', '47', '75', '93', '82', '41', '98', '19', '37'], ['85', '86', '38', '56', '29', '82', '76', '43', '31', '72', '93', '99', '33', '53', '94'], ['55', '85', '66', '43', '49', '42', '53', '77', '86', '56', '89'], ['97', '72', '63', '19', '57', '23', '89', '24', '47'], ['45', '98', '93', '37', '94', '57', '82', '69', '35', '36', '22', '63', '24', '19', '39'], ['49', '82', '53', '63', '59', '96', '72', '22', '87', '29', '69', '45', '23', '56', '67', '76', '93', '41', '94'], ['49', '66', '68', '75', '89', '36', '97', '38', '57', '34', '73', '86', '91', '99', '29', '62', '53', '11', '39'], ['69', '14', '86', '57', '68', '34', '75', '42', '62'], ['77', '76', '94', '59', '41', '29', '87', '63', '67', '96', '72', '82', '23', '33', '55', '56', '69', '49', '19', '43', '31'], ['87', '69', '91', '59', '82', '45', '63', '96', '67', '76', '94', '23', '55', '98', '37', '77', '47', '75', '93'], ['94', '41', '37', '93', '55', '76', '82', '72', '77', '67', '45', '96', '98', '56', '87', '31', '33'], ['94', '53', '72', '96', '82', '43', '55'], ['45', '98', '33', '77', '47', '69', '59', '87', '19', '67', '23', '31', '94'], ['35', '24', '98', '45', '91', '57', '87', '37', '11', '36', '89', '63', '39', '75', '42', '96', '23', '47', '19', '73', '69'], ['99', '22', '53', '56', '82', '59', '72', '33', '31', '85', '63', '68', '76', '34', '77', '93', '43', '94', '29'], ['62', '49', '68', '93', '56', '59', '77', '85', '41', '66', '86', '22', '11', '82', '38'], ['14', '53', '97', '41', '42', '66', '33', '11', '85'], ['45', '19', '98', '73', '69', '91', '82', '22', '23', '96', '47', '36', '75', '63', '94', '72', '57', '67', '24'], ['63', '69', '94', '45', '47', '87', '72', '97', '39'], ['36', '66', '91', '37', '29', '38', '39'], ['68', '56', '66', '41', '62', '99', '97', '67', '31', '86', '49', '33', '77', '29', '85', '43', '34', '11', '38', '55', '53'], ['14', '29', '36', '42', '37', '43', '73', '34', '85', '62', '99', '38', '39', '11', '68', '24', '91', '35', '57'], ['68', '39', '55', '53', '31', '11', '33', '86', '56', '14', '62', '49', '42', '97', '43'], ['38', '56', '77', '33', '53', '86', '41', '22', '76'], ['82', '87', '72', '22', '63', '75', '69', '76', '24', '35', '23', '73', '39', '57', '47', '36', '91', '89', '96', '94', '45', '98', '19'], ['14', '97', '45', '87', '35', '73', '23', '85', '66'], ['75', '36', '69', '91', '39', '42', '68', '11', '34'], ['59', '22', '33', '41', '77', '49', '68', '38', '63', '99', '29', '67', '72', '94', '31', '19', '56'], ['47', '14', '39', '87', '75', '45', '97', '36', '73', '86', '42'], ['38', '82', '34', '59', '68', '56', '67', '22', '31', '55', '76', '77', '41', '29', '53', '99', '85', '94', '43', '93', '63'], ['9 ...

# %%
# build a graph based on given rules

G = d5.build_rule_graph(rules)

#G.edges()

# %%
manual_invalid_fixed = list() 


for m in tqdm(manual_invalid):
    m_fixed = d5.fix_manual_graph(G, rules, m)

    if m_fixed != None: manual_invalid_fixed.append(m_fixed)

#manual_invalid_fixed
# Out:
# 100%|██████████| 103/103 [03:26<00:00,  2.00s/it]

# %%
d5.sum_middle_numbers(manual_invalid_fixed)  # 5833
# Out:
# 5833
